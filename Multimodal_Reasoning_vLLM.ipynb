# %%
# !nvcc --version

# !pip install git+https://github.com/huggingface/transformers@21fac7abba2a37fae86106f87fcf9974fd1e3830
# !pip install git+https://github.com/huggingface/transformers
# !pip install accelerate
# !pip install qwen-vl-utils
# !pip install datasets
# !CUDA_VERSION=cu121
# !pip install 'vllm==0.6.1' --extra-index-url https://download.pytorch.org/whl/${CUDA_VERSION}
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-w8zc86at
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-w8zc86at
#   Resolved https://github.com/huggingface/transformers to commit b2f2977533445c4f62bf58e10b1360e6856e78ce
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (2024.12.14)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.48.0.dev0-py3-none-any.whl size=10291149 sha256=a3dd3be04ff176aa072ad5426b68aed373b46b38269fef16f5ca491c79cfcf16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gm3sbx09/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# Successfully installed transformers-4.48.0.dev0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.12.14)
# Collecting qwen-vl-utils
#   Downloading qwen_vl_utils-0.0.8-py3-none-any.whl.metadata (3.6 kB)
# Collecting av (from qwen-vl-utils)
#   Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qwen-vl-utils) (24.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from qwen-vl-utils) (11.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from qwen-vl-utils) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->qwen-vl-utils) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->qwen-vl-utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->qwen-vl-utils) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->qwen-vl-utils) (2024.12.14)
# Downloading qwen_vl_utils-0.0.8-py3-none-any.whl (5.9 kB)
# Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 68.7 MB/s eta 0:00:00
# Installing collected packages: av, qwen-vl-utils
# Successfully installed av-14.0.1 qwen-vl-utils-0.0.8
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 30.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/12.2.2
# Collecting vllm==0.6.1
#   Downloading vllm-0.6.1-cp38-abi3-manylinux1_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (4.67.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (9.0.0)
# Requirement already satisfied: transformers>=4.43.2 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (4.48.0.dev0)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (4.25.5)
# Collecting fastapi (from vllm==0.6.1)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (3.11.10)
# Requirement already satisfied: openai>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (1.57.4)
# Collecting uvicorn[standard] (from vllm==0.6.1)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=2.8 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (2.10.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (11.0.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (0.21.1)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm==0.6.1)
#   Downloading prometheus_fastapi_instrumentator-7.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm==0.6.1)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting lm-format-enforcer==0.10.6 (from vllm==0.6.1)
#   Downloading lm_format_enforcer-0.10.6-py3-none-any.whl.metadata (16 kB)
# Collecting outlines<0.1,>=0.0.43 (from vllm==0.6.1)
#   Downloading outlines-0.0.46-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (4.12.2)
# Requirement already satisfied: filelock>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (3.16.1)
# Collecting partial-json-parser (from vllm==0.6.1)
#   Downloading partial_json_parser-0.2.1.1.post4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (24.0.1)
# Collecting msgspec (from vllm==0.6.1)
#   Downloading msgspec-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.9.1 (from vllm==0.6.1)
#   Downloading gguf-0.9.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (8.5.0)
# Collecting mistral-common>=1.4.0 (from vllm==0.6.1)
#   Downloading mistral_common-1.5.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from vllm==0.6.1) (0.8.0)
# Collecting ray>=2.9 (from vllm==0.6.1)
#   Downloading ray-2.40.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting nvidia-ml-py (from vllm==0.6.1)
#   Downloading nvidia_ml_py-12.560.30-py3-none-any.whl.metadata (8.6 kB)
# Collecting torch==2.4.0 (from vllm==0.6.1)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.19 (from vllm==0.6.1)
#   Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting xformers==0.0.27.post2 (from vllm==0.6.1)
#   Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting vllm-flash-attn==2.6.1 (from vllm==0.6.1)
#   Downloading vllm_flash_attn-2.6.1-cp310-cp310-manylinux1_x86_64.whl.metadata (476 bytes)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.10.6->vllm==0.6.1)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lm-format-enforcer==0.10.6->vllm==0.6.1) (24.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm==0.6.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm==0.6.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm==0.6.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm==0.6.1) (2024.9.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.0->vllm==0.6.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch==2.4.0->vllm==0.6.1)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->vllm==0.6.1) (12.6.85)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /usr/local/lib/python3.10/dist-packages (from mistral-common>=1.4.0->vllm==0.6.1) (4.23.0)
# Collecting pillow (from vllm==0.6.1)
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting tiktoken>=0.6.0 (from vllm==0.6.1)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm==0.6.1) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm==0.6.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm==0.6.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm==0.6.1) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm==0.6.1) (1.3.1)
# Collecting lark (from outlines<0.1,>=0.0.43->vllm==0.6.1)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.1) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.1) (3.1.0)
# Collecting diskcache (from outlines<0.1,>=0.0.43->vllm==0.6.1)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.1) (0.60.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.1) (0.35.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.1) (3.2.0)
# Collecting pycountry (from outlines<0.1,>=0.0.43->vllm==0.6.1)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting pyairports (from outlines<0.1,>=0.0.43->vllm==0.6.1)
#   Downloading pyairports-2.1.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting starlette<1.0.0,>=0.30.0 (from prometheus-fastapi-instrumentator>=7.0.0->vllm==0.6.1)
#   Downloading starlette-0.45.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.8->vllm==0.6.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.8->vllm==0.6.1) (2.27.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.6.1) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.6.1) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.6.1) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm==0.6.1) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.6.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.6.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.6.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vllm==0.6.1) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.6.0->vllm==0.6.1) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.19.1->vllm==0.6.1) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.43.2->vllm==0.6.1) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (2.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm==0.6.1) (1.18.3)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->vllm==0.6.1) (3.21.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]->vllm==0.6.1) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]->vllm==0.6.1)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm==0.6.1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm==0.6.1)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm==0.6.1)
#   Downloading watchfiles-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]->vllm==0.6.1) (14.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.40.0->vllm==0.6.1) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.40.0->vllm==0.6.1) (1.0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.0->vllm==0.6.1) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.0->vllm==0.6.1) (0.22.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (0.70.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0->vllm==0.6.1) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->outlines<0.1,>=0.0.43->vllm==0.6.1) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0->vllm==0.6.1) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.1) (1.17.0)
# Downloading vllm-0.6.1-cp38-abi3-manylinux1_x86_64.whl (170.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.6/170.6 MB 5.5 MB/s eta 0:00:00
# Downloading gguf-0.9.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.0 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.6-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.3 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.5 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 85.0 MB/s eta 0:00:00
# Downloading vllm_flash_attn-2.6.1-cp310-cp310-manylinux1_x86_64.whl (75.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 MB 29.2 MB/s eta 0:00:00
# Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 86.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 87.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 38.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 18.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.8 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.0 MB/s eta 0:00:00
# Downloading mistral_common-1.5.1-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 9.6 MB/s eta 0:00:00
# Downloading outlines-0.0.46-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 10.4 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 94.1 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.0.0-py3-none-any.whl (19 kB)
# Downloading ray-2.40.0-cp310-cp310-manylinux2014_x86_64.whl (66.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 MB 33.4 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.7 MB/s eta 0:00:00
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.6 MB/s eta 0:00:00
# Downloading msgspec-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.6/211.6 kB 21.6 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.560.30-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 4.0 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post4-py3-none-any.whl (9.9 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 40.5 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.1 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 98.7 MB/s eta 0:00:00
# Downloading watchfiles-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.8/443.8 kB 36.0 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.8 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.4 MB/s eta 0:00:00
# Downloading pyairports-2.1.1-py3-none-any.whl (371 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 34.9 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 108.0 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: pyairports, nvidia-ml-py, uvloop, uvicorn, triton, python-dotenv, pycountry, pillow, partial-json-parser, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, msgspec, lark, interegular, httptools, gguf, diskcache, watchfiles, tiktoken, starlette, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, prometheus-fastapi-instrumentator, lm-format-enforcer, fastapi, xformers, vllm-flash-attn, torchvision, ray, mistral-common, outlines, vllm
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.6.0.74
#     Uninstalling nvidia-cudnn-cu12-9.6.0.74:
#       Successfully uninstalled nvidia-cudnn-cu12-9.6.0.74
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
# Successfully installed diskcache-5.6.3 fastapi-0.115.6 gguf-0.9.1 httptools-0.6.4 interegular-0.3.3 lark-1.2.2 lm-format-enforcer-0.10.6 mistral-common-1.5.1 msgspec-0.19.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-ml-py-12.560.30 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 outlines-0.0.46 partial-json-parser-0.2.1.1.post4 pillow-10.4.0 prometheus-fastapi-instrumentator-7.0.0 pyairports-2.1.1 pycountry-24.6.1 python-dotenv-1.0.1 ray-2.40.0 starlette-0.41.3 tiktoken-0.7.0 torch-2.4.0 torchvision-0.19.0 triton-3.0.0 uvicorn-0.34.0 uvloop-0.21.0 vllm-0.6.1 vllm-flash-attn-2.6.1 watchfiles-1.0.3 xformers-0.0.27.post2

# %%
from google.colab import drive
import os
import json
import re
import torch
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info
from datasets import load_dataset

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Create necessary directories in Google Drive
output_dir = "/content/drive/My Drive/World Models"
os.makedirs(output_dir, exist_ok=True)

# Use GPU
if torch.cuda.is_available():
    print("GPU is available and ready to use!")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available. Make sure it's enabled in the runtime settings.")

# Response Generation with vLLM
from vllm import LLM, SamplingParams
from transformers import AutoProcessor
from qwen_vl_utils import process_vision_info
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GPU is available and ready to use!
# Device name: NVIDIA A100-SXM4-40GB

# %%
model_save_path = os.path.join(output_dir, "qwen_model")
if os.path.exists(model_save_path):
    print("Loading model from local save path.")
    model_path = model_save_path
else:
    print("Downloading model. This may take some time...")
    model = Qwen2VLForConditionalGeneration.from_pretrained(
        "Qwen/Qwen2-VL-2B-Instruct", torch_dtype="auto", device_map="auto"
    )
    processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-2B-Instruct")
    model.save_pretrained(model_save_path)
    processor.save_pretrained(model_save_path)
# Out:
# Loading model from local save path.

# %%
print(model_save_path)
print(model_path)
# Out:
# /content/drive/My Drive/World Models/qwen_model
# /content/drive/My Drive/World Models/qwen_model

# %%
from transformers import AutoConfig

config = AutoConfig.from_pretrained(model_path)
if not hasattr(config, "rope_scaling") or "factor" not in config.rope_scaling:
    config.rope_scaling = {"type": "linear", "factor": 1.0}  # Default
if not hasattr(config, "rope_type"):
    config.rope_type = "yarn"  # Default
if not hasattr(config, "max_model_len"):
    config.max_model_len = 2048  # Adjust per the model

config.save_pretrained(model_path)

# %%
# from transformers import AutoTokenizer
# model_name = "Qwen/Qwen2-VL-2B-Instruct"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# tokenizer.save_pretrained(model_path)

llm = LLM(
    model=model_path,
    limit_mm_per_prompt={"image": 10, "video": 10},
    dtype=torch.float16,
)

sampling_params = SamplingParams(
    temperature=0.1,
    top_p=0.001,
    repetition_penalty=1.05,
    max_tokens=256,
    stop_token_ids=[],
)

# Load the MathVista dataset
dataset = load_dataset("AI4Math/MathVista")
# Out:
# WARNING 01-05 18:47:10 config.py:1650] Casting torch.bfloat16 to torch.float16.
# INFO 01-05 18:47:10 llm_engine.py:232] Initializing an LLM engine (v0.6.1) with config: model='/content/drive/My Drive/World Models/qwen_model', speculative_config=None, tokenizer='/content/drive/My Drive/World Models/qwen_model', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=/content/drive/My Drive/World Models/qwen_model, use_v2_block_manager=False, num_scheduler_steps=1, enable_prefix_caching=False, use_async_output_proc=True)
# INFO 01-05 18:47:11 model_runner.py:997] Starting to load model /content/drive/My Drive/World Models/qwen_model...
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# WARNING 01-05 18:47:11 qwen2_vl.py:217] Current Qwen2-VL implementation has a bug with `vllm-flash-attn` inside vision module, so we use xformers backend instead. You can run `pip install flash-attn to use flash-attention backend.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 01-05 18:48:40 model_runner.py:1008] Loading model weights took 4.1277 GB
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:211: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_fwd")
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:344: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_bwd")
# INFO 01-05 18:48:44 gpu_executor.py:122] # GPU blocks: 60586, # CPU blocks: 9362
# INFO 01-05 18:48:47 model_runner.py:1309] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 01-05 18:48:47 model_runner.py:1313] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 01-05 18:49:12 model_runner.py:1428] Graph capturing finished in 25 secs.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# (…)-00000-of-00001-725687bf7a18d64b.parquet:   0%|          | 0.00/142M [00:00<?, ?B/s]
# (…)-00000-of-00002-6b81bd7f7e2065e6.parquet:   0%|          | 0.00/358M [00:00<?, ?B/s]
# (…)-00001-of-00002-6a611c71596db30f.parquet:   0%|          | 0.00/386M [00:00<?, ?B/s]
# Generating testmini split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5141 [00:00<?, ? examples/s]

# %%
subset_dataset = dataset["testmini"]

# Prepare results storage
responses = {}

import time
start_time = time.time()

# Generate responses
for idx, example in enumerate(subset_dataset):

    query = example["query"]  # Use the query field directly from the dataset
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": example["decoded_image"]},
                {"type": "text", "text": query},
            ],
        }
    ]
    processor = AutoProcessor.from_pretrained(model_path)
    prompt = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, _ = process_vision_info(messages)

    mm_data = {}
    if image_inputs is not None:
        mm_data["image"] = image_inputs

    llm_inputs = {
        "prompt": prompt,
        "multi_modal_data": mm_data,
    }

    outputs = llm.generate([llm_inputs], sampling_params=sampling_params)
    response = outputs[0].outputs[0].text
    # response_cleaned = response.split("\nassistant\n")[-1].strip()

    responses[example["pid"]] = {
        "query": query,
        "response": response,
        "question_type": example["question_type"],
        "answer_type": example["answer_type"],
        "choices": example.get("choices"),
        "precision": example.get("precision"),
        "answer": example["answer"],
    }



time_cost = time.time() - start_time
print(f"Time cost for generating responses: {time_cost:.2f} seconds")

responses_file = os.path.join(output_dir, "responses.json")
with open(responses_file, "w") as f:
    json.dump(responses, f)

print(f"Response generation completed. Saved to {responses_file}.")
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it, est. speed input: 856.68 toks/s, output: 132.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s, est. speed input: 4655.87 toks/s, output: 17.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it, est. speed input: 127.02 toks/s, output: 133.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.71it/s, est. speed input: 1845.68 toks/s, output: 21.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.99it/s, est. speed input: 1941.51 toks/s, output: 30.02 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.27it/s, est. speed input: 1225.02 toks/s, output: 30.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.27it/s, est. speed input: 1501.86 toks/s, output: 30.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.84it/s, est. speed input: 4346.79 toks/s, output: 17.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s, est. speed input: 285.35 toks/s, output: 120.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.51it/s, est. speed input: 2621.01 toks/s, output: 28.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.76it/s, est. speed input: 1843.45 toks/s, output: 21.56 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.08it/s, est. speed input: 4228.60 toks/s, output: 18.38 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s, est. speed input: 3264.03 toks/s, output: 19.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.02it/s, est. speed input: 4365.98 toks/s, output: 18.30 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.36it/s, est. speed input: 1877.18 toks/s, output: 28.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.77it/s, est. speed input: 3228.75 toks/s, output: 19.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s, est. speed input: 260.58 toks/s, output: 112.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 201.04 toks/s, output: 149.17 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.95it/s, est. speed input: 5705.71 toks/s, output: 23.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.48it/s, est. speed input: 5052.26 toks/s, output: 21.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s, est. speed input: 1963.38 toks/s, output: 20.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.80it/s, est. speed input: 3701.71 toks/s, output: 11.73 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.15it/s, est. speed input: 3381.51 toks/s, output: 27.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.30it/s, est. speed input: 3923.26 toks/s, output: 18.81 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.43it/s, est. speed input: 3933.36 toks/s, output: 25.59 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.29it/s, est. speed input: 3744.43 toks/s, output: 25.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.59s/it, est. speed input: 3778.64 toks/s, output: 1.26 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.64s/it, est. speed input: 241.69 toks/s, output: 144.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s, est. speed input: 4242.21 toks/s, output: 18.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.15it/s, est. speed input: 1454.21 toks/s, output: 30.50 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.86it/s, est. speed input: 4242.94 toks/s, output: 17.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s, est. speed input: 218.58 toks/s, output: 115.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s, est. speed input: 1725.24 toks/s, output: 30.99 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.02it/s, est. speed input: 3259.79 toks/s, output: 27.39 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s, est. speed input: 229.84 toks/s, output: 122.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.24it/s, est. speed input: 4707.67 toks/s, output: 16.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s, est. speed input: 1096.29 toks/s, output: 60.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.64it/s, est. speed input: 3134.81 toks/s, output: 19.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.40it/s, est. speed input: 2212.43 toks/s, output: 28.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.94it/s, est. speed input: 1884.25 toks/s, output: 21.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:06<00:00,  6.88s/it, est. speed input: 2368.73 toks/s, output: 0.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.51it/s, est. speed input: 3249.70 toks/s, output: 19.22 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s, est. speed input: 2576.65 toks/s, output: 27.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s, est. speed input: 335.14 toks/s, output: 114.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s, est. speed input: 186.48 toks/s, output: 131.57 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s, est. speed input: 4879.48 toks/s, output: 12.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.77it/s, est. speed input: 1845.62 toks/s, output: 21.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.78s/it, est. speed input: 225.51 toks/s, output: 144.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s, est. speed input: 639.70 toks/s, output: 130.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.13it/s, est. speed input: 4917.19 toks/s, output: 24.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.94it/s, est. speed input: 2375.94 toks/s, output: 34.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.68it/s, est. speed input: 1862.80 toks/s, output: 21.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.67it/s, est. speed input: 3894.53 toks/s, output: 11.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.51it/s, est. speed input: 2762.90 toks/s, output: 28.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s, est. speed input: 249.38 toks/s, output: 123.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s, est. speed input: 180.19 toks/s, output: 136.43 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.83it/s, est. speed input: 1855.30 toks/s, output: 21.69 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.32it/s, est. speed input: 3778.61 toks/s, output: 25.24 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.23it/s, est. speed input: 1578.89 toks/s, output: 30.75 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.87it/s, est. speed input: 2791.03 toks/s, output: 18.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.59it/s, est. speed input: 1555.11 toks/s, output: 16.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s, est. speed input: 233.41 toks/s, output: 116.70 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.41it/s, est. speed input: 1805.18 toks/s, output: 20.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.92it/s, est. speed input: 3658.02 toks/s, output: 27.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.26it/s, est. speed input: 1998.86 toks/s, output: 28.15 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it, est. speed input: 242.09 toks/s, output: 140.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s, est. speed input: 271.75 toks/s, output: 125.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.64it/s, est. speed input: 412.72 toks/s, output: 121.69 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.04it/s, est. speed input: 1901.96 toks/s, output: 22.11 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it, est. speed input: 3638.92 toks/s, output: 0.96 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s, est. speed input: 175.47 toks/s, output: 134.57 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it, est. speed input: 122.33 toks/s, output: 139.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.64s/it, est. speed input: 245.68 toks/s, output: 145.45 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s, est. speed input: 2494.36 toks/s, output: 67.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.38it/s, est. speed input: 3180.14 toks/s, output: 28.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.75it/s, est. speed input: 4150.64 toks/s, output: 11.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.51it/s, est. speed input: 1631.84 toks/s, output: 90.51 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.62it/s, est. speed input: 2754.94 toks/s, output: 41.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.12it/s, est. speed input: 1499.91 toks/s, output: 30.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.53it/s, est. speed input: 1862.00 toks/s, output: 28.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.70it/s, est. speed input: 1569.03 toks/s, output: 59.63 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.71s/it, est. speed input: 92.55 toks/s, output: 149.96 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.00it/s, est. speed input: 4244.65 toks/s, output: 18.21 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s, est. speed input: 4445.13 toks/s, output: 11.19 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.12it/s, est. speed input: 5759.95 toks/s, output: 16.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s, est. speed input: 4725.86 toks/s, output: 5.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s, est. speed input: 400.66 toks/s, output: 132.05 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s, est. speed input: 1686.22 toks/s, output: 64.02 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s, est. speed input: 1565.33 toks/s, output: 56.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.76it/s, est. speed input: 1853.85 toks/s, output: 21.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.98it/s, est. speed input: 4263.91 toks/s, output: 18.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s, est. speed input: 1639.71 toks/s, output: 37.51 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.16it/s, est. speed input: 3450.83 toks/s, output: 25.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s, est. speed input: 193.72 toks/s, output: 125.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 85.96 toks/s, output: 148.68 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.63it/s, est. speed input: 1388.94 toks/s, output: 43.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.61it/s, est. speed input: 3137.22 toks/s, output: 19.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s, est. speed input: 2642.25 toks/s, output: 41.22 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.29it/s, est. speed input: 4067.26 toks/s, output: 18.83 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s, est. speed input: 1334.50 toks/s, output: 65.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.46it/s, est. speed input: 4798.10 toks/s, output: 22.59 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.16it/s, est. speed input: 1062.51 toks/s, output: 22.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.66it/s, est. speed input: 1826.42 toks/s, output: 21.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s, est. speed input: 1802.54 toks/s, output: 51.37 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.33it/s, est. speed input: 3666.75 toks/s, output: 25.28 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.55it/s, est. speed input: 3107.26 toks/s, output: 19.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.39it/s, est. speed input: 1090.13 toks/s, output: 59.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.36it/s, est. speed input: 3115.30 toks/s, output: 21.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.69it/s, est. speed input: 1831.01 toks/s, output: 21.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.88it/s, est. speed input: 3465.53 toks/s, output: 9.84 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.88it/s, est. speed input: 1886.15 toks/s, output: 21.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.13it/s, est. speed input: 4333.38 toks/s, output: 18.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.65it/s, est. speed input: 4183.69 toks/s, output: 17.50 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it, est. speed input: 148.59 toks/s, output: 144.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s, est. speed input: 4731.90 toks/s, output: 7.62 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.78it/s, est. speed input: 1644.92 toks/s, output: 29.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.10it/s, est. speed input: 2772.89 toks/s, output: 27.63 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s, est. speed input: 573.49 toks/s, output: 110.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.22it/s, est. speed input: 1730.71 toks/s, output: 30.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s, est. speed input: 424.30 toks/s, output: 99.15 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s, est. speed input: 374.04 toks/s, output: 113.54 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, est. speed input: 4372.65 toks/s, output: 18.76 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.14it/s, est. speed input: 2503.54 toks/s, output: 18.59 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.39it/s, est. speed input: 2424.30 toks/s, output: 28.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.70it/s, est. speed input: 4098.97 toks/s, output: 11.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.84it/s, est. speed input: 5657.63 toks/s, output: 15.84 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s, est. speed input: 3213.30 toks/s, output: 19.71 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.73it/s, est. speed input: 1837.42 toks/s, output: 21.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.95it/s, est. speed input: 868.20 toks/s, output: 49.89 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.78it/s, est. speed input: 3523.38 toks/s, output: 33.96 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s, est. speed input: 2668.76 toks/s, output: 57.92 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it, est. speed input: 129.94 toks/s, output: 139.68 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.25it/s, est. speed input: 4738.58 toks/s, output: 8.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it, est. speed input: 283.19 toks/s, output: 144.95 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.96it/s, est. speed input: 4403.17 toks/s, output: 18.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.05it/s, est. speed input: 2839.51 toks/s, output: 27.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.52it/s, est. speed input: 1576.61 toks/s, output: 29.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.96it/s, est. speed input: 4153.31 toks/s, output: 18.13 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.00it/s, est. speed input: 3047.59 toks/s, output: 27.37 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s, est. speed input: 3923.69 toks/s, output: 18.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.19it/s, est. speed input: 1735.87 toks/s, output: 30.63 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.07it/s, est. speed input: 3774.22 toks/s, output: 18.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.15it/s, est. speed input: 1424.10 toks/s, output: 30.51 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.08it/s, est. speed input: 832.96 toks/s, output: 73.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s, est. speed input: 2716.71 toks/s, output: 38.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.97it/s, est. speed input: 615.06 toks/s, output: 63.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.24it/s, est. speed input: 3785.01 toks/s, output: 28.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.56it/s, est. speed input: 2002.60 toks/s, output: 29.02 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s, est. speed input: 279.45 toks/s, output: 109.15 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.34it/s, est. speed input: 1647.30 toks/s, output: 31.07 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.49it/s, est. speed input: 3053.94 toks/s, output: 28.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s, est. speed input: 417.97 toks/s, output: 103.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.89it/s, est. speed input: 3560.04 toks/s, output: 26.96 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s, est. speed input: 4121.13 toks/s, output: 7.19 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.08it/s, est. speed input: 3352.60 toks/s, output: 27.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.08it/s, est. speed input: 591.07 toks/s, output: 83.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.60s/it, est. speed input: 181.44 toks/s, output: 148.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s, est. speed input: 4414.73 toks/s, output: 10.22 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s, est. speed input: 4132.46 toks/s, output: 13.82 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.14it/s, est. speed input: 1615.20 toks/s, output: 30.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s, est. speed input: 1442.61 toks/s, output: 88.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.70s/it, est. speed input: 72.23 toks/s, output: 150.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it, est. speed input: 284.34 toks/s, output: 141.19 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.77it/s, est. speed input: 1520.78 toks/s, output: 32.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.71it/s, est. speed input: 1844.98 toks/s, output: 21.45 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s, est. speed input: 4420.89 toks/s, output: 14.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.11s/it, est. speed input: 2290.12 toks/s, output: 71.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.29it/s, est. speed input: 3448.34 toks/s, output: 28.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s, est. speed input: 4402.52 toks/s, output: 9.57 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.52it/s, est. speed input: 2965.87 toks/s, output: 28.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.64it/s, est. speed input: 1767.88 toks/s, output: 29.30 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s, est. speed input: 3193.23 toks/s, output: 28.51 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.22it/s, est. speed input: 4484.89 toks/s, output: 18.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.03it/s, est. speed input: 4296.52 toks/s, output: 18.28 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.11it/s, est. speed input: 3028.92 toks/s, output: 27.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s, est. speed input: 206.60 toks/s, output: 139.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.32it/s, est. speed input: 4516.36 toks/s, output: 18.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it, est. speed input: 152.89 toks/s, output: 140.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s, est. speed input: 196.93 toks/s, output: 134.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.03it/s, est. speed input: 1900.81 toks/s, output: 22.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, est. speed input: 3825.76 toks/s, output: 26.02 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.94it/s, est. speed input: 3266.17 toks/s, output: 27.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.74it/s, est. speed input: 1829.98 toks/s, output: 21.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.80it/s, est. speed input: 3185.10 toks/s, output: 19.84 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.65it/s, est. speed input: 4062.57 toks/s, output: 26.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.43it/s, est. speed input: 2184.72 toks/s, output: 31.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 168.58 toks/s, output: 148.81 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s, est. speed input: 3586.10 toks/s, output: 46.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.40it/s, est. speed input: 3067.07 toks/s, output: 19.05 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.51it/s, est. speed input: 1667.14 toks/s, output: 21.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s, est. speed input: 4295.96 toks/s, output: 7.92 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.68it/s, est. speed input: 1497.32 toks/s, output: 32.08 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.72it/s, est. speed input: 1815.81 toks/s, output: 21.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s, est. speed input: 1663.53 toks/s, output: 64.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s, est. speed input: 205.48 toks/s, output: 122.05 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s, est. speed input: 208.73 toks/s, output: 130.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s, est. speed input: 3977.09 toks/s, output: 26.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.69it/s, est. speed input: 4437.27 toks/s, output: 14.15 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.73s/it, est. speed input: 189.06 toks/s, output: 148.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s, est. speed input: 2726.99 toks/s, output: 20.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s, est. speed input: 3022.85 toks/s, output: 27.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.00it/s, est. speed input: 3204.71 toks/s, output: 20.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s, est. speed input: 209.50 toks/s, output: 131.75 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.91it/s, est. speed input: 3083.17 toks/s, output: 18.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s, est. speed input: 644.99 toks/s, output: 74.99 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it, est. speed input: 605.20 toks/s, output: 135.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.06it/s, est. speed input: 1331.62 toks/s, output: 69.43 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.06it/s, est. speed input: 1696.12 toks/s, output: 22.17 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.07it/s, est. speed input: 3350.49 toks/s, output: 25.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s, est. speed input: 1237.64 toks/s, output: 73.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.81it/s, est. speed input: 3200.84 toks/s, output: 19.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.49it/s, est. speed input: 2518.49 toks/s, output: 28.83 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s, est. speed input: 3270.61 toks/s, output: 30.19 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s, est. speed input: 4469.05 toks/s, output: 8.21 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.18it/s, est. speed input: 647.05 toks/s, output: 71.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.55it/s, est. speed input: 3140.61 toks/s, output: 28.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s, est. speed input: 262.09 toks/s, output: 117.93 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.81it/s, est. speed input: 1884.48 toks/s, output: 21.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.74it/s, est. speed input: 3158.32 toks/s, output: 19.74 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.33it/s, est. speed input: 1510.35 toks/s, output: 31.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.36it/s, est. speed input: 1411.30 toks/s, output: 31.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.62it/s, est. speed input: 1840.15 toks/s, output: 21.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.86it/s, est. speed input: 4292.79 toks/s, output: 8.62 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s, est. speed input: 4640.59 toks/s, output: 8.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s, est. speed input: 2109.57 toks/s, output: 72.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.36it/s, est. speed input: 1206.54 toks/s, output: 22.76 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.11it/s, est. speed input: 3328.12 toks/s, output: 27.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.20it/s, est. speed input: 1471.25 toks/s, output: 30.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it, est. speed input: 4059.20 toks/s, output: 5.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.87it/s, est. speed input: 3257.71 toks/s, output: 19.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s, est. speed input: 4289.51 toks/s, output: 11.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.06it/s, est. speed input: 2296.62 toks/s, output: 30.21 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.74it/s, est. speed input: 2044.68 toks/s, output: 21.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.88it/s, est. speed input: 2928.27 toks/s, output: 26.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.50it/s, est. speed input: 2135.02 toks/s, output: 28.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it, est. speed input: 182.68 toks/s, output: 146.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.80it/s, est. speed input: 2600.62 toks/s, output: 29.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.14it/s, est. speed input: 1614.86 toks/s, output: 30.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.65it/s, est. speed input: 3883.95 toks/s, output: 26.24 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.57s/it, est. speed input: 2997.06 toks/s, output: 0.56 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s, est. speed input: 4190.58 toks/s, output: 32.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it, est. speed input: 270.24 toks/s, output: 147.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s, est. speed input: 3791.99 toks/s, output: 14.31 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.16it/s, est. speed input: 2986.67 toks/s, output: 27.82 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.43it/s, est. speed input: 1154.68 toks/s, output: 38.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it, est. speed input: 390.70 toks/s, output: 144.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.83s/it, est. speed input: 688.31 toks/s, output: 140.07 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.14it/s, est. speed input: 4355.76 toks/s, output: 18.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.64it/s, est. speed input: 1834.30 toks/s, output: 21.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 128.66 toks/s, output: 149.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.97it/s, est. speed input: 1868.43 toks/s, output: 21.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it, est. speed input: 190.05 toks/s, output: 137.69 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.88it/s, est. speed input: 2947.72 toks/s, output: 17.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.00it/s, est. speed input: 4363.12 toks/s, output: 18.21 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.48it/s, est. speed input: 1648.47 toks/s, output: 31.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s, est. speed input: 164.09 toks/s, output: 133.25 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it, est. speed input: 120.32 toks/s, output: 137.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.71s/it, est. speed input: 83.30 toks/s, output: 150.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.50it/s, est. speed input: 1819.23 toks/s, output: 21.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.37it/s, est. speed input: 2616.62 toks/s, output: 28.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.67it/s, est. speed input: 2833.41 toks/s, output: 19.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.59it/s, est. speed input: 2224.79 toks/s, output: 72.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s, est. speed input: 171.21 toks/s, output: 117.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it, est. speed input: 3654.98 toks/s, output: 13.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.38it/s, est. speed input: 382.31 toks/s, output: 109.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.27it/s, est. speed input: 1543.85 toks/s, output: 30.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.17it/s, est. speed input: 2805.04 toks/s, output: 27.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s, est. speed input: 718.14 toks/s, output: 65.28 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.21it/s, est. speed input: 2055.31 toks/s, output: 30.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.25it/s, est. speed input: 1498.74 toks/s, output: 30.79 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.57it/s, est. speed input: 2296.88 toks/s, output: 29.07 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.01it/s, est. speed input: 1814.06 toks/s, output: 30.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.67it/s, est. speed input: 2112.48 toks/s, output: 29.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s, est. speed input: 133.58 toks/s, output: 135.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.54it/s, est. speed input: 1932.14 toks/s, output: 31.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.06it/s, est. speed input: 1350.49 toks/s, output: 30.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.93it/s, est. speed input: 3576.45 toks/s, output: 27.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.39it/s, est. speed input: 4523.32 toks/s, output: 7.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.99it/s, est. speed input: 3601.62 toks/s, output: 27.28 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.43it/s, est. speed input: 1348.00 toks/s, output: 31.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.12it/s, est. speed input: 3792.47 toks/s, output: 18.45 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.48it/s, est. speed input: 3541.47 toks/s, output: 25.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it, est. speed input: 227.20 toks/s, output: 146.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.18it/s, est. speed input: 3284.98 toks/s, output: 20.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.15it/s, est. speed input: 1413.08 toks/s, output: 30.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s, est. speed input: 313.81 toks/s, output: 115.93 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.75it/s, est. speed input: 2509.81 toks/s, output: 29.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it, est. speed input: 931.00 toks/s, output: 130.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.71it/s, est. speed input: 2038.05 toks/s, output: 21.45 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s, est. speed input: 300.74 toks/s, output: 99.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.80it/s, est. speed input: 5357.65 toks/s, output: 23.63 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.13it/s, est. speed input: 2707.64 toks/s, output: 27.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.65it/s, est. speed input: 1818.19 toks/s, output: 29.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it, est. speed input: 138.98 toks/s, output: 146.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.11it/s, est. speed input: 2490.72 toks/s, output: 20.25 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.02it/s, est. speed input: 4585.07 toks/s, output: 9.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.20it/s, est. speed input: 4356.22 toks/s, output: 18.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s, est. speed input: 3683.79 toks/s, output: 14.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s, est. speed input: 4547.76 toks/s, output: 4.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it, est. speed input: 335.12 toks/s, output: 144.50 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s, est. speed input: 4676.80 toks/s, output: 19.22 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.54it/s, est. speed input: 2829.72 toks/s, output: 28.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.50it/s, est. speed input: 3952.12 toks/s, output: 25.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s, est. speed input: 756.17 toks/s, output: 85.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.14it/s, est. speed input: 3250.19 toks/s, output: 20.31 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.14it/s, est. speed input: 3882.21 toks/s, output: 18.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it, est. speed input: 404.71 toks/s, output: 147.59 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.68it/s, est. speed input: 2509.12 toks/s, output: 29.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s, est. speed input: 256.05 toks/s, output: 111.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.03it/s, est. speed input: 1980.10 toks/s, output: 30.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s, est. speed input: 4380.72 toks/s, output: 2.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.55it/s, est. speed input: 1542.92 toks/s, output: 31.70 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.19it/s, est. speed input: 2939.02 toks/s, output: 20.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.75it/s, est. speed input: 3270.05 toks/s, output: 19.75 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.05it/s, est. speed input: 5204.93 toks/s, output: 24.39 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.30it/s, est. speed input: 1454.20 toks/s, output: 30.93 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.09it/s, est. speed input: 3091.27 toks/s, output: 20.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.02it/s, est. speed input: 1545.47 toks/s, output: 30.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.17it/s, est. speed input: 2403.35 toks/s, output: 36.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s, est. speed input: 177.64 toks/s, output: 135.70 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.68it/s, est. speed input: 482.31 toks/s, output: 105.08 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.67it/s, est. speed input: 278.55 toks/s, output: 129.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s, est. speed input: 169.61 toks/s, output: 137.08 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s, est. speed input: 4295.42 toks/s, output: 15.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, est. speed input: 2767.85 toks/s, output: 28.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.60it/s, est. speed input: 1848.46 toks/s, output: 21.24 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.85it/s, est. speed input: 3253.22 toks/s, output: 19.95 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.18it/s, est. speed input: 3037.63 toks/s, output: 27.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.79s/it, est. speed input: 3750.30 toks/s, output: 1.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.71it/s, est. speed input: 1824.27 toks/s, output: 21.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it, est. speed input: 137.95 toks/s, output: 141.93 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s, est. speed input: 225.24 toks/s, output: 119.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.15it/s, est. speed input: 1687.48 toks/s, output: 30.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.06it/s, est. speed input: 4395.13 toks/s, output: 18.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.62it/s, est. speed input: 1829.51 toks/s, output: 21.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.08it/s, est. speed input: 3283.30 toks/s, output: 20.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.60it/s, est. speed input: 924.30 toks/s, output: 52.31 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it, est. speed input: 102.12 toks/s, output: 145.19 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s, est. speed input: 200.11 toks/s, output: 126.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s, est. speed input: 4255.97 toks/s, output: 9.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.70it/s, est. speed input: 924.40 toks/s, output: 52.81 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.14it/s, est. speed input: 2211.94 toks/s, output: 27.76 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.51it/s, est. speed input: 1821.70 toks/s, output: 21.05 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.10it/s, est. speed input: 4398.81 toks/s, output: 18.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.80it/s, est. speed input: 3896.48 toks/s, output: 17.83 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it, est. speed input: 144.92 toks/s, output: 144.92 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.35it/s, est. speed input: 4456.59 toks/s, output: 18.92 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.58it/s, est. speed input: 2922.62 toks/s, output: 19.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s, est. speed input: 4353.85 toks/s, output: 8.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.22it/s, est. speed input: 1304.71 toks/s, output: 22.49 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.12it/s, est. speed input: 4345.60 toks/s, output: 18.45 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.86it/s, est. speed input: 1311.05 toks/s, output: 86.25 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it, est. speed input: 801.38 toks/s, output: 139.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.85it/s, est. speed input: 3222.35 toks/s, output: 19.95 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.37it/s, est. speed input: 1537.64 toks/s, output: 31.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.15it/s, est. speed input: 4287.16 toks/s, output: 18.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.34it/s, est. speed input: 3800.10 toks/s, output: 18.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.26it/s, est. speed input: 2812.89 toks/s, output: 28.12 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s, est. speed input: 696.77 toks/s, output: 66.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 270.93 toks/s, output: 149.15 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.88it/s, est. speed input: 3807.58 toks/s, output: 26.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.65it/s, est. speed input: 1836.58 toks/s, output: 21.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.62it/s, est. speed input: 1829.26 toks/s, output: 21.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.11it/s, est. speed input: 1499.07 toks/s, output: 30.38 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.73it/s, est. speed input: 1860.50 toks/s, output: 21.50 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.69it/s, est. speed input: 1677.01 toks/s, output: 19.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.39it/s, est. speed input: 4562.14 toks/s, output: 16.99 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.06it/s, est. speed input: 4308.19 toks/s, output: 18.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s, est. speed input: 1823.70 toks/s, output: 28.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s, est. speed input: 3510.88 toks/s, output: 12.54 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s, est. speed input: 223.62 toks/s, output: 119.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.87it/s, est. speed input: 1851.87 toks/s, output: 21.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.39it/s, est. speed input: 1936.91 toks/s, output: 31.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.77it/s, est. speed input: 1234.61 toks/s, output: 68.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 200.45 toks/s, output: 148.73 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.97it/s, est. speed input: 1901.65 toks/s, output: 21.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.34it/s, est. speed input: 3675.95 toks/s, output: 18.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s, est. speed input: 187.18 toks/s, output: 122.21 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.17it/s, est. speed input: 3429.03 toks/s, output: 27.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s, est. speed input: 3354.37 toks/s, output: 10.37 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.76it/s, est. speed input: 4211.88 toks/s, output: 17.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.68it/s, est. speed input: 3177.41 toks/s, output: 19.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s, est. speed input: 2176.08 toks/s, output: 65.74 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.03it/s, est. speed input: 4269.57 toks/s, output: 18.28 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.41it/s, est. speed input: 3928.07 toks/s, output: 25.50 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.22it/s, est. speed input: 1402.15 toks/s, output: 30.70 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.67it/s, est. speed input: 2880.59 toks/s, output: 19.59 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it, est. speed input: 105.80 toks/s, output: 146.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.43it/s, est. speed input: 436.86 toks/s, output: 109.82 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.22it/s, est. speed input: 4414.14 toks/s, output: 18.66 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.54it/s, est. speed input: 1542.83 toks/s, output: 31.69 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.78it/s, est. speed input: 228.19 toks/s, output: 115.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.86it/s, est. speed input: 5151.88 toks/s, output: 23.81 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s, est. speed input: 4293.36 toks/s, output: 12.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s, est. speed input: 1537.75 toks/s, output: 67.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.30it/s, est. speed input: 5318.86 toks/s, output: 16.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s, est. speed input: 257.48 toks/s, output: 105.23 toks/s]
# ...
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.88it/s, est. speed input: 4259.65 toks/s, output: 17.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.49it/s, est. speed input: 1996.77 toks/s, output: 21.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s, est. speed input: 4010.64 toks/s, output: 11.71 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.00it/s, est. speed input: 3296.55 toks/s, output: 20.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it, est. speed input: 306.32 toks/s, output: 137.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.70it/s, est. speed input: 1823.07 toks/s, output: 21.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it, est. speed input: 134.46 toks/s, output: 145.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.78it/s, est. speed input: 3232.93 toks/s, output: 19.83 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s, est. speed input: 158.79 toks/s, output: 137.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.77it/s, est. speed input: 1867.21 toks/s, output: 21.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s, est. speed input: 3449.35 toks/s, output: 24.22 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.16it/s, est. speed input: 3355.02 toks/s, output: 27.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s, est. speed input: 3804.22 toks/s, output: 18.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.08it/s, est. speed input: 1417.86 toks/s, output: 46.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.01it/s, est. speed input: 2391.82 toks/s, output: 40.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s, est. speed input: 263.54 toks/s, output: 109.47 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s, est. speed input: 270.68 toks/s, output: 123.73 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.62it/s, est. speed input: 1510.13 toks/s, output: 31.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.49it/s, est. speed input: 1817.96 toks/s, output: 21.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s, est. speed input: 2822.33 toks/s, output: 27.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.56it/s, est. speed input: 4371.39 toks/s, output: 5.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.99it/s, est. speed input: 3263.68 toks/s, output: 20.02 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, est. speed input: 4506.14 toks/s, output: 17.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s, est. speed input: 447.16 toks/s, output: 109.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.06it/s, est. speed input: 3283.77 toks/s, output: 20.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.54it/s, est. speed input: 4378.24 toks/s, output: 7.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.10it/s, est. speed input: 4536.03 toks/s, output: 24.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it, est. speed input: 112.81 toks/s, output: 146.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.68it/s, est. speed input: 1476.81 toks/s, output: 32.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it, est. speed input: 150.39 toks/s, output: 138.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s, est. speed input: 4389.69 toks/s, output: 18.88 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.70it/s, est. speed input: 1844.48 toks/s, output: 21.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s, est. speed input: 4514.06 toks/s, output: 4.76 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.65it/s, est. speed input: 1312.84 toks/s, output: 32.01 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.33it/s, est. speed input: 2547.44 toks/s, output: 20.71 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.09it/s, est. speed input: 4427.09 toks/s, output: 18.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.39it/s, est. speed input: 5267.18 toks/s, output: 14.96 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s, est. speed input: 3335.96 toks/s, output: 23.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.48it/s, est. speed input: 2762.17 toks/s, output: 28.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.45it/s, est. speed input: 1570.68 toks/s, output: 31.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.82it/s, est. speed input: 1863.96 toks/s, output: 21.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.98it/s, est. speed input: 3807.96 toks/s, output: 18.17 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, est. speed input: 3763.38 toks/s, output: 18.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, est. speed input: 3891.94 toks/s, output: 26.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.65it/s, est. speed input: 1845.65 toks/s, output: 21.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.83it/s, est. speed input: 4632.30 toks/s, output: 23.71 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.43it/s, est. speed input: 2068.45 toks/s, output: 31.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s, est. speed input: 3980.17 toks/s, output: 9.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  6.35it/s, est. speed input: 2571.99 toks/s, output: 57.57 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.84it/s, est. speed input: 3246.53 toks/s, output: 19.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s, est. speed input: 1175.03 toks/s, output: 46.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s, est. speed input: 1508.22 toks/s, output: 30.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.02it/s, est. speed input: 3260.50 toks/s, output: 20.06 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s, est. speed input: 4094.38 toks/s, output: 21.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, est. speed input: 3432.81 toks/s, output: 28.13 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.79it/s, est. speed input: 450.44 toks/s, output: 89.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.61it/s, est. speed input: 2211.85 toks/s, output: 43.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.64it/s, est. speed input: 264.40 toks/s, output: 123.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s, est. speed input: 197.27 toks/s, output: 128.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.46it/s, est. speed input: 1263.30 toks/s, output: 38.27 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s, est. speed input: 210.30 toks/s, output: 126.77 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.74it/s, est. speed input: 1667.53 toks/s, output: 32.26 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.65it/s, est. speed input: 3595.76 toks/s, output: 26.24 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s, est. speed input: 244.38 toks/s, output: 123.82 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s, est. speed input: 1059.98 toks/s, output: 82.81 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it, est. speed input: 108.89 toks/s, output: 140.91 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s, est. speed input: 3038.00 toks/s, output: 62.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.03it/s, est. speed input: 4221.29 toks/s, output: 18.31 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it, est. speed input: 185.08 toks/s, output: 143.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s, est. speed input: 4817.51 toks/s, output: 11.87 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.64it/s, est. speed input: 1823.31 toks/s, output: 21.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s, est. speed input: 365.41 toks/s, output: 117.17 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s, est. speed input: 1525.95 toks/s, output: 57.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.81it/s, est. speed input: 4231.80 toks/s, output: 7.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s, est. speed input: 146.35 toks/s, output: 139.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.34it/s, est. speed input: 4005.70 toks/s, output: 18.89 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.87it/s, est. speed input: 3316.97 toks/s, output: 19.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s, est. speed input: 227.60 toks/s, output: 124.14 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it, est. speed input: 129.21 toks/s, output: 142.90 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.79it/s, est. speed input: 5116.07 toks/s, output: 23.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s, est. speed input: 4150.61 toks/s, output: 10.72 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it, est. speed input: 254.57 toks/s, output: 144.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.10it/s, est. speed input: 2538.96 toks/s, output: 30.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.63it/s, est. speed input: 3596.31 toks/s, output: 26.18 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.64it/s, est. speed input: 2614.07 toks/s, output: 29.26 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s, est. speed input: 226.81 toks/s, output: 125.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.06it/s, est. speed input: 1917.28 toks/s, output: 22.16 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.18it/s, est. speed input: 4421.35 toks/s, output: 18.57 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.82s/it, est. speed input: 578.82 toks/s, output: 140.85 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s, est. speed input: 407.32 toks/s, output: 105.38 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s, est. speed input: 4391.44 toks/s, output: 2.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.12it/s, est. speed input: 5283.40 toks/s, output: 16.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.66it/s, est. speed input: 2342.35 toks/s, output: 29.40 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.65it/s, est. speed input: 1061.21 toks/s, output: 73.43 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 11.08it/s, est. speed input: 1154.90 toks/s, output: 22.20 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s, est. speed input: 3896.67 toks/s, output: 11.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.54it/s, est. speed input: 1837.27 toks/s, output: 21.11 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.20it/s, est. speed input: 4321.56 toks/s, output: 8.44 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.66it/s, est. speed input: 1837.37 toks/s, output: 21.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.00it/s, est. speed input: 3321.83 toks/s, output: 27.30 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.65it/s, est. speed input: 383.42 toks/s, output: 98.51 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.39it/s, est. speed input: 3972.17 toks/s, output: 19.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.02it/s, est. speed input: 4282.97 toks/s, output: 18.26 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.40s/it, est. speed input: 1974.41 toks/s, output: 75.37 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, est. speed input: 4387.55 toks/s, output: 18.75 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.61it/s, est. speed input: 1675.98 toks/s, output: 19.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.91it/s, est. speed input: 4326.94 toks/s, output: 18.10 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.91it/s, est. speed input: 307.86 toks/s, output: 118.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s, est. speed input: 726.80 toks/s, output: 71.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s, est. speed input: 640.46 toks/s, output: 110.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  4.67it/s, est. speed input: 1912.72 toks/s, output: 61.09 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s, est. speed input: 2241.94 toks/s, output: 77.07 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.73it/s, est. speed input: 4633.32 toks/s, output: 17.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.77it/s, est. speed input: 3184.51 toks/s, output: 19.78 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s, est. speed input: 4420.28 toks/s, output: 18.89 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  7.77it/s, est. speed input: 5067.39 toks/s, output: 15.69 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s, est. speed input: 172.44 toks/s, output: 130.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 332.61 toks/s, output: 148.60 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s, est. speed input: 2973.61 toks/s, output: 20.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.56it/s, est. speed input: 3134.99 toks/s, output: 19.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s, est. speed input: 410.57 toks/s, output: 136.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.07it/s, est. speed input: 3523.13 toks/s, output: 27.52 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.29it/s, est. speed input: 4484.58 toks/s, output: 18.80 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.52it/s, est. speed input: 1833.43 toks/s, output: 21.07 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  8.72it/s, est. speed input: 3079.32 toks/s, output: 26.46 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s, est. speed input: 3466.00 toks/s, output: 25.98 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.90it/s, est. speed input: 1877.71 toks/s, output: 21.83 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  9.72it/s, est. speed input: 2051.36 toks/s, output: 29.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it, est. speed input: 147.07 toks/s, output: 139.48 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s, est. speed input: 420.28 toks/s, output: 136.56 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00, 10.73it/s, est. speed input: 1859.40 toks/s, output: 21.49 toks/s]
# Time cost for generating responses: 1781.47 seconds
# Response generation completed. Saved to /content/drive/My Drive/World Models/responses.json.
